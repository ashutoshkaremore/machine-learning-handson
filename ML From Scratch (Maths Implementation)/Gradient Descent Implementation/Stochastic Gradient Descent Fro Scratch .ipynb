# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import SGDRegressor

# %%
X,y = load_diabetes(return_X_y=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state = 2)

# %%
# Stochastic Gradient Descent
import random

class SGDRegressor_:
  def __init__(self, lr = 0.01, epochs = 100):
    self.lr = lr
    self.epochs = epochs
    self.coef_ = None
    self.intercept_ = None

  def fit(self, X, y):
    self.coef_ = np.ones(X.shape[1])
    self.intercept_ = 0

    for i in range(self.epochs):
      for j in range(X.shape[0]):
        idx = random.randint(0, X.shape[0]-1)
        y_hat = np.dot(X[idx], self.coef_ ) + self.intercept_ # y=mx+b

        derivative_intercept_ = -2 * (y[idx] - y_hat)
        self.intercept_ = self.intercept_ - (self.lr * derivative_intercept_)

        derivative_coef_ = -2 * np.dot((y[idx] - y_hat) , X[idx])
        self.coef_ = self.coef_ - (self.lr * derivative_coef_)

    print('Intercept :' , self.intercept_)
    print('Coef :' , self.coef_)

  def predict(self,X_test):
    return np.dot( X_test, self.coef_) + self.intercept_

# %%
sgd_model = SGDRegressor_(lr = 0.01, epochs = 40)
sgd_model.fit(X_train,y_train)
y_pred_sgd = sgd_model.predict(X_test)
print('r2-score = ', r2_score(y_test, y_pred_sgd))
# Out:
# Intercept : 146.70751966090938
# Coef : [  59.83702624  -55.16111238  313.86252112  226.14077205   30.81210574
#   -14.56192712 -152.49603965  118.68536374  290.93700072  120.52132863]
# r2-score =  0.41423295631790524

# %%
sgd_sk_model = SGDRegressor(learning_rate= 'constant', max_iter= 200)
sgd_sk_model.fit(X_train,y_train)

y_pred_sk = sgd_sk_model.predict(X_test)
print('Intercept :' , sgd_sk_model.intercept_)
print('Coef :' , sgd_sk_model.coef_)
print('r2-score = ', r2_score(y_test, y_pred_sk))
# Out:
# Intercept : [148.4262937]
# Coef : [  44.67340931 -100.37038308  398.16268139  275.03956188   -0.97333143
#   -58.14509118 -183.32761107  122.68235594  359.993717    124.16987606]
# r2-score =  0.4436390600236252
